# %%
###           Written and Executed By:            ####
###               Sheekar Banerjee                ####
###        Senior Software Engineer- AI & ML      ####

# Breast Cancer Detection
# Ultrasound Image
# Efficient-Net-B6 (EfficientNetB6)
# Accuracy 97.86 %

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, activations, optimizers, losses, metrics, initializers
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV3Small, MobileNet, InceptionV3
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input, decode_predictions
from tensorflow.keras.applications.densenet import preprocess_input, decode_predictions

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dir_path = '/content/drive/MyDrive/breast ultra'
IMAGE_SHAPE = (224, 224)

# %%
# create prepare_image method
# used to preprocess the image for efficientNet model
def prepare_image(file):
    img = image.load_img(file, target_size=IMAGE_SHAPE)
    img_array = image.img_to_array(img)
    return tf.keras.applications.efficientnet.preprocess_input (img_array)

# %%
directories = os.listdir(dir_path) # read the folders

files = [] # save all images for each folder
labels = [] # set for each image the name of it

# read files for each directory
for folder in directories:
    
    fileList = glob.glob(dir_path + '/'+ folder + '/*')
    labels.extend([folder for l in fileList])
    files.extend(fileList)
    
len(files), len(labels)
# Out:
# (1578, 1578)

# %%
# create two lists to hold only non-mask images and label for each one
selected_files = []
selected_labels = []

for file, label in zip(files, labels):
    if 'mask' not in file:
        selected_files.append(file)
        selected_labels.append(label)

    
len(selected_files), len(selected_labels)
# Out:
# (780, 780)

# %%
# the dictionary holds list of images and for each one has its target/label
images = {
    'image': [], 
    'target': []
}

print('Preparing the image...')

for i, (file, label) in enumerate(zip(selected_files, selected_labels)):
    images['image'].append(prepare_image(file))
    images['target'].append(label)

print('Finished.')
# Out:
# Preparing the image...
# Finished.

# %%
# convert lists to arrays 
images['image'] = np.array(images['image'])
images['target'] = np.array(images['target'])

# encode the target
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

images['target'] = le.fit_transform(images['target'])

classes = le.classes_ # get the classes for each target
print(f'the target classes are: {classes}')
# Out:
# the target classes are: ['benign' 'malignant' 'normal']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(images['image'], images['target'], test_size=.10)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((702, 224, 224, 3), (78, 224, 224, 3), (702,), (78,))

# %%
#Build Model

from keras.applications.efficientnet import EfficientNetB6

base_model = EfficientNetB6(
    include_top=False,
    weights='imagenet',
    input_shape=(*IMAGE_SHAPE, 3),
    classes=3)

# Freeze the base_model
base_model.trainable = False

# append my own layers on the top of the model for Transfer Learning
x = base_model.output

# 1st conv block
x = layers.Conv2D(256, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 2nd conv block
x = layers.Conv2D(128, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 1st FC layer
x = layers.Flatten()(x) 
x = layers.Dense(64)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# 2nd FC layer
x = layers.Dense(32, activation = 'relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(.2)(x)

x = layers.Dense(3, 'softmax')(x)

incept_model = keras.models.Model(inputs = base_model.input, outputs = x)

# compile the model
incept_model.compile(optimizer=optimizers.RMSprop(.001), loss = losses.sparse_categorical_crossentropy, metrics= [metrics.SparseCategoricalAccuracy()])

incept_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165240832/165234480 [==============================] - 3s 0us/step
# 165249024/165234480 [==============================] - 3s 0us/step
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_7 (Rescaling)        (None, 224, 224, 3)  0           ['input_8[0][0]']
#
#  normalization_7 (Normalization  (None, 224, 224, 3)  7          ['rescaling_7[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['normalization_7[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 56  1512        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 56  224         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 56  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 112, 112, 56  504        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 112, 112, 56  224        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 112, 112, 56  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 56)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 56)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 14)     798         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 56)     840         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 112, 112, 56  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 32  1792        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 112, 112, 32  288        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 112, 112, 32  128        ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 112, 112, 32  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 112, 112, 32  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 112, 112, 32  1024        ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 112, 112, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 112, 112, 32  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 112, 112, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 112, 112, 32  288        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 112, 112, 32  128        ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 112, 112, 32  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 112, 112, 32  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 112, 112, 32  1024        ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 112, 112, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 112, 112, 32  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 112, 112, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 112, 112, 19  6144        ['block1c_add[0][0]']
#                                 2)
#
#  block2a_expand_bn (BatchNormal  (None, 112, 112, 19  768        ['block2a_expand_conv[0][0]']
#  ization)                       2)
#
#  block2a_expand_activation (Act  (None, 112, 112, 19  0          ['block2a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 113, 113, 19  0          ['block2a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 56, 56, 192)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 40)   7680        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 40)  160         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 240)  9600        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 240)  960        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 240)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 56, 56, 240)  2160       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 56, 56, 240)  960        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 56, 56, 240)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 56, 56, 240)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 40)   9600        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 40)  160         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 56, 56, 40)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 56, 56, 40)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 56, 56, 240)  9600        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 56, 56, 240)  960        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 56, 56, 240)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 56, 56, 240)  2160       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 56, 56, 240)  960        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 56, 56, 240)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 56, 56, 240)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 56, 56, 40)   9600        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 56, 56, 40)  160         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 56, 56, 40)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 56, 56, 40)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 56, 56, 240)  9600        ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 56, 56, 240)  960        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 56, 56, 240)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 56, 56, 240)  2160       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 56, 56, 240)  960        ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 56, 56, 240)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 56, 56, 240)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 56, 56, 40)   9600        ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 56, 56, 40)  160         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 56, 56, 40)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 56, 56, 40)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 56, 56, 240)  9600        ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 56, 56, 240)  960        ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 56, 56, 240)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 56, 56, 240)  2160       ['block2e_expand_activation[0][0]
#  D)                                                              ']
#
#  block2e_bn (BatchNormalization  (None, 56, 56, 240)  960        ['block2e_dwconv[0][0]']
#  )
#
#  block2e_activation (Activation  (None, 56, 56, 240)  0          ['block2e_bn[0][0]']
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 56, 56, 240)  0           ['block2e_activation[0][0]',
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 56, 56, 40)   9600        ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 56, 56, 40)  160         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 56, 56, 40)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 56, 56, 40)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 56, 56, 240)  9600        ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 56, 56, 240)  960        ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 56, 56, 240)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 56, 56, 240)  2160       ['block2f_expand_activation[0][0]
#  D)                                                              ']
#
#  block2f_bn (BatchNormalization  (None, 56, 56, 240)  960        ['block2f_dwconv[0][0]']
#  )
#
#  block2f_activation (Activation  (None, 56, 56, 240)  0          ['block2f_bn[0][0]']
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 240)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 56, 56, 240)  0           ['block2f_activation[0][0]',
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 56, 56, 40)   9600        ['block2f_se_excite[0][0]']
#
#  block2f_project_bn (BatchNorma  (None, 56, 56, 40)  160         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (Dropout)         (None, 56, 56, 40)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 56, 56, 40)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 56, 56, 240)  9600        ['block2f_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 56, 56, 240)  960        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 56, 56, 240)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 59, 59, 240)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 28, 28, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 28, 28, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 28, 28, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 28, 28, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 72)   17280       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 72)  288         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 432)  31104       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 432)  1728       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 432)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 28, 28, 432)  10800      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 28, 28, 432)  1728       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 28, 28, 432)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 432)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 432)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 18)     7794        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 432)    8208        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 28, 28, 432)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 72)   31104       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 72)  288         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 28, 28, 72)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 28, 28, 72)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 28, 28, 432)  31104       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 28, 28, 432)  1728       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 28, 28, 432)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 28, 28, 432)  10800      ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 28, 28, 432)  1728       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 28, 28, 432)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 432)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 432)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 18)     7794        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 432)    8208        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 28, 28, 432)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 28, 28, 72)   31104       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 28, 28, 72)  288         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 28, 28, 72)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 28, 28, 72)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 28, 28, 432)  31104       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 28, 28, 432)  1728       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 28, 28, 432)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 28, 28, 432)  10800      ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 28, 28, 432)  1728       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 28, 28, 432)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 432)         0           ['block3d_activation[0][0]']
#  agePooling2D)
# ...
#  block7a_expand_bn (BatchNormal  (None, 7, 7, 2064)  8256        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 7, 7, 2064)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 7, 7, 2064)  18576       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 7, 7, 2064)  8256        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 7, 7, 2064)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 2064)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2064)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 86)     177590      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2064)   179568      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 7, 7, 2064)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 7, 7, 576)    1188864     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 7, 7, 576)   2304        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 7, 7, 3456)   1990656     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 7, 7, 3456)  13824       ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 7, 7, 3456)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 7, 7, 3456)  31104       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 7, 7, 3456)  13824       ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 7, 7, 3456)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3456)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3456)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 144)    497808      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3456)   501120      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 7, 7, 3456)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 7, 7, 576)    1990656     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 7, 7, 576)   2304        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 7, 7, 576)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 7, 7, 576)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 7, 7, 3456)   1990656     ['block7b_add[0][0]']
#
#  block7c_expand_bn (BatchNormal  (None, 7, 7, 3456)  13824       ['block7c_expand_conv[0][0]']
#  ization)
#
#  block7c_expand_activation (Act  (None, 7, 7, 3456)  0           ['block7c_expand_bn[0][0]']
#  ivation)
#
#  block7c_dwconv (DepthwiseConv2  (None, 7, 7, 3456)  31104       ['block7c_expand_activation[0][0]
#  D)                                                              ']
#
#  block7c_bn (BatchNormalization  (None, 7, 7, 3456)  13824       ['block7c_dwconv[0][0]']
#  )
#
#  block7c_activation (Activation  (None, 7, 7, 3456)  0           ['block7c_bn[0][0]']
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3456)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3456)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 144)    497808      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3456)   501120      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 7, 7, 3456)   0           ['block7c_activation[0][0]',
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 7, 7, 576)    1990656     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 7, 7, 576)   2304        ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 7, 7, 576)    0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 7, 7, 576)    0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 7, 7, 2304)   1327104     ['block7c_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 2304)   9216        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 2304)   0           ['top_bn[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 256)    5308672     ['top_activation[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_28[0][0]']
#
#  global_average_pooling2d_14 (G  (None, 1, 1, 256)   0           ['activation_28[0][0]']
#  lobalAveragePooling2D)
#
#  conv2d_15 (Conv2D)             (None, 1, 1, 128)    295040      ['global_average_pooling2d_14[0][
#                                                                  0]']
#
#  batch_normalization_29 (BatchN  (None, 1, 1, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 1, 1, 128)    0           ['batch_normalization_29[0][0]']
#
#  global_average_pooling2d_15 (G  (None, 1, 1, 128)   0           ['activation_29[0][0]']
#  lobalAveragePooling2D)
#
#  flatten_7 (Flatten)            (None, 128)          0           ['global_average_pooling2d_15[0][
#                                                                  0]']
#
#  dense_21 (Dense)               (None, 64)           8256        ['flatten_7[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64)          256         ['dense_21[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 64)           0           ['batch_normalization_30[0][0]']
#
#  dense_22 (Dense)               (None, 32)           2080        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32)          128         ['dense_22[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32)           0           ['batch_normalization_31[0][0]']
#
#  dropout_7 (Dropout)            (None, 32)           0           ['activation_31[0][0]']
#
#  dense_23 (Dense)               (None, 3)            99          ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 46,576,210
# Trainable params: 5,615,107
# Non-trainable params: 40,961,103
# __________________________________________________________________________________________________

# %%
earlyStop = keras.callbacks.EarlyStopping(patience=60) 
best_model = keras.callbacks.ModelCheckpoint(filepath='breast_Neurals_sheekar.h5', save_best_only=True) 

with tf.device('/gpu:0'):
    history = incept_model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data=(x_test, y_test), callbacks=[earlyStop, best_model])
# Out:
# Epoch 1/100
# 22/22 [==============================] - 34s 649ms/step - loss: 1.1248 - sparse_categorical_accuracy: 0.5100 - val_loss: 1.1157 - val_sparse_categorical_accuracy: 0.2821
# Epoch 2/100
# 22/22 [==============================] - 8s 384ms/step - loss: 0.7833 - sparse_categorical_accuracy: 0.6738 - val_loss: 0.9922 - val_sparse_categorical_accuracy: 0.5000
# Epoch 3/100
# 22/22 [==============================] - 8s 383ms/step - loss: 0.6770 - sparse_categorical_accuracy: 0.7564 - val_loss: 0.9334 - val_sparse_categorical_accuracy: 0.6154
# Epoch 4/100
# 22/22 [==============================] - 8s 347ms/step - loss: 0.5393 - sparse_categorical_accuracy: 0.8219 - val_loss: 1.0122 - val_sparse_categorical_accuracy: 0.5000
# Epoch 5/100
# 22/22 [==============================] - 8s 391ms/step - loss: 0.4973 - sparse_categorical_accuracy: 0.8162 - val_loss: 0.7699 - val_sparse_categorical_accuracy: 0.6923
# Epoch 6/100
# 22/22 [==============================] - 7s 322ms/step - loss: 0.4235 - sparse_categorical_accuracy: 0.8433 - val_loss: 0.9768 - val_sparse_categorical_accuracy: 0.5385
# Epoch 7/100
# 22/22 [==============================] - 7s 323ms/step - loss: 0.3950 - sparse_categorical_accuracy: 0.8348 - val_loss: 0.8918 - val_sparse_categorical_accuracy: 0.6795
# Epoch 8/100
# 22/22 [==============================] - 7s 324ms/step - loss: 0.3969 - sparse_categorical_accuracy: 0.8504 - val_loss: 0.8544 - val_sparse_categorical_accuracy: 0.6154
# Epoch 9/100
# 22/22 [==============================] - 8s 353ms/step - loss: 0.2980 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.7852 - val_sparse_categorical_accuracy: 0.6795
# Epoch 10/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.2875 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.9262 - val_sparse_categorical_accuracy: 0.6410
# Epoch 11/100
# 22/22 [==============================] - 9s 391ms/step - loss: 0.2309 - sparse_categorical_accuracy: 0.9259 - val_loss: 0.7595 - val_sparse_categorical_accuracy: 0.7051
# Epoch 12/100
# 22/22 [==============================] - 9s 392ms/step - loss: 0.2925 - sparse_categorical_accuracy: 0.8974 - val_loss: 0.7102 - val_sparse_categorical_accuracy: 0.7179
# Epoch 13/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.2219 - sparse_categorical_accuracy: 0.9259 - val_loss: 1.2240 - val_sparse_categorical_accuracy: 0.6154
# Epoch 14/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.2301 - sparse_categorical_accuracy: 0.9060 - val_loss: 0.8991 - val_sparse_categorical_accuracy: 0.6282
# Epoch 15/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.2434 - sparse_categorical_accuracy: 0.9060 - val_loss: 1.3633 - val_sparse_categorical_accuracy: 0.6795
# Epoch 16/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.2271 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.8825 - val_sparse_categorical_accuracy: 0.7051
# Epoch 17/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1666 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.7767 - val_sparse_categorical_accuracy: 0.7564
# Epoch 18/100
# 22/22 [==============================] - 8s 354ms/step - loss: 0.1933 - sparse_categorical_accuracy: 0.9245 - val_loss: 0.8550 - val_sparse_categorical_accuracy: 0.7949
# Epoch 19/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1933 - sparse_categorical_accuracy: 0.9330 - val_loss: 0.9969 - val_sparse_categorical_accuracy: 0.7564
# Epoch 20/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1397 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.9720 - val_sparse_categorical_accuracy: 0.7179
# Epoch 21/100
# 22/22 [==============================] - 9s 391ms/step - loss: 0.1584 - sparse_categorical_accuracy: 0.9459 - val_loss: 0.7054 - val_sparse_categorical_accuracy: 0.7821
# Epoch 22/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1405 - sparse_categorical_accuracy: 0.9487 - val_loss: 1.2059 - val_sparse_categorical_accuracy: 0.6795
# Epoch 23/100
# 22/22 [==============================] - 8s 389ms/step - loss: 0.1455 - sparse_categorical_accuracy: 0.9487 - val_loss: 0.6927 - val_sparse_categorical_accuracy: 0.7564
# Epoch 24/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1383 - sparse_categorical_accuracy: 0.9558 - val_loss: 1.1257 - val_sparse_categorical_accuracy: 0.7179
# Epoch 25/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.8650 - val_sparse_categorical_accuracy: 0.7564
# Epoch 26/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.1060 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.9283 - val_sparse_categorical_accuracy: 0.7821
# Epoch 27/100
# 22/22 [==============================] - 9s 416ms/step - loss: 0.1573 - sparse_categorical_accuracy: 0.9416 - val_loss: 0.6821 - val_sparse_categorical_accuracy: 0.7821
# Epoch 28/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0980 - sparse_categorical_accuracy: 0.9701 - val_loss: 1.0492 - val_sparse_categorical_accuracy: 0.7436
# Epoch 29/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1177 - sparse_categorical_accuracy: 0.9601 - val_loss: 1.9004 - val_sparse_categorical_accuracy: 0.6923
# Epoch 30/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1319 - sparse_categorical_accuracy: 0.9516 - val_loss: 1.5230 - val_sparse_categorical_accuracy: 0.7179
# Epoch 31/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1312 - sparse_categorical_accuracy: 0.9615 - val_loss: 1.4305 - val_sparse_categorical_accuracy: 0.6795
# Epoch 32/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0875 - sparse_categorical_accuracy: 0.9729 - val_loss: 2.4890 - val_sparse_categorical_accuracy: 0.6795
# Epoch 33/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1368 - sparse_categorical_accuracy: 0.9530 - val_loss: 1.5128 - val_sparse_categorical_accuracy: 0.7564
# Epoch 34/100
# 22/22 [==============================] - 8s 353ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9829 - val_loss: 1.6296 - val_sparse_categorical_accuracy: 0.6923
# Epoch 35/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1460 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.9313 - val_sparse_categorical_accuracy: 0.7564
# Epoch 36/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1028 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.0545 - val_sparse_categorical_accuracy: 0.7436
# Epoch 37/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1257 - sparse_categorical_accuracy: 0.9573 - val_loss: 1.7875 - val_sparse_categorical_accuracy: 0.7051
# Epoch 38/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0542 - sparse_categorical_accuracy: 0.9843 - val_loss: 2.0836 - val_sparse_categorical_accuracy: 0.6923
# Epoch 39/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1198 - sparse_categorical_accuracy: 0.9530 - val_loss: 1.0171 - val_sparse_categorical_accuracy: 0.7564
# Epoch 40/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.6193 - val_sparse_categorical_accuracy: 0.7179
# Epoch 41/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0998 - sparse_categorical_accuracy: 0.9658 - val_loss: 0.9472 - val_sparse_categorical_accuracy: 0.7821
# Epoch 42/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9672 - val_loss: 1.6297 - val_sparse_categorical_accuracy: 0.6795
# Epoch 43/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0776 - sparse_categorical_accuracy: 0.9729 - val_loss: 1.0908 - val_sparse_categorical_accuracy: 0.7179
# Epoch 44/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9672 - val_loss: 1.1455 - val_sparse_categorical_accuracy: 0.7436
# Epoch 45/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.4578 - val_sparse_categorical_accuracy: 0.7564
# Epoch 46/100
# 22/22 [==============================] - 8s 354ms/step - loss: 0.0622 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.7851 - val_sparse_categorical_accuracy: 0.8077
# Epoch 47/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0675 - sparse_categorical_accuracy: 0.9815 - val_loss: 1.1930 - val_sparse_categorical_accuracy: 0.7308
# Epoch 48/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0998 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.8370 - val_sparse_categorical_accuracy: 0.7821
# Epoch 49/100
# 22/22 [==============================] - 8s 354ms/step - loss: 0.0605 - sparse_categorical_accuracy: 0.9801 - val_loss: 1.2703 - val_sparse_categorical_accuracy: 0.7051
# Epoch 50/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.1097 - sparse_categorical_accuracy: 0.9687 - val_loss: 1.1687 - val_sparse_categorical_accuracy: 0.7308
# Epoch 51/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0859 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.1567 - val_sparse_categorical_accuracy: 0.7692
# Epoch 52/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9758 - val_loss: 2.1598 - val_sparse_categorical_accuracy: 0.6667
# Epoch 53/100
# 22/22 [==============================] - 8s 355ms/step - loss: 0.0923 - sparse_categorical_accuracy: 0.9658 - val_loss: 1.3116 - val_sparse_categorical_accuracy: 0.7308
# Epoch 54/100
# 22/22 [==============================] - 8s 354ms/step - loss: 0.0590 - sparse_categorical_accuracy: 0.9801 - val_loss: 1.2176 - val_sparse_categorical_accuracy: 0.7564
# Epoch 55/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.1769 - val_sparse_categorical_accuracy: 0.7564
# Epoch 56/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0865 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.3666 - val_sparse_categorical_accuracy: 0.6795
# Epoch 57/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.8845 - val_sparse_categorical_accuracy: 0.7821
# Epoch 58/100
# 22/22 [==============================] - 7s 324ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9744 - val_loss: 1.3664 - val_sparse_categorical_accuracy: 0.7564
# Epoch 59/100
# 22/22 [==============================] - 7s 324ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9829 - val_loss: 2.5017 - val_sparse_categorical_accuracy: 0.6795
# Epoch 60/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.4570 - val_sparse_categorical_accuracy: 0.7564
# Epoch 61/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9801 - val_loss: 1.4008 - val_sparse_categorical_accuracy: 0.7436
# Epoch 62/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9772 - val_loss: 1.2336 - val_sparse_categorical_accuracy: 0.7821
# Epoch 63/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.0397 - val_sparse_categorical_accuracy: 0.7949
# Epoch 64/100
# 22/22 [==============================] - 8s 354ms/step - loss: 0.0690 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.0087 - val_sparse_categorical_accuracy: 0.7949
# Epoch 65/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0793 - sparse_categorical_accuracy: 0.9744 - val_loss: 0.8290 - val_sparse_categorical_accuracy: 0.8590
# Epoch 66/100
# 22/22 [==============================] - 7s 329ms/step - loss: 0.0657 - sparse_categorical_accuracy: 0.9744 - val_loss: 1.2142 - val_sparse_categorical_accuracy: 0.7821
# Epoch 67/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0643 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.5619 - val_sparse_categorical_accuracy: 0.7564
# Epoch 68/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0771 - sparse_categorical_accuracy: 0.9744 - val_loss: 1.2527 - val_sparse_categorical_accuracy: 0.7821
# Epoch 69/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0875 - sparse_categorical_accuracy: 0.9744 - val_loss: 0.9493 - val_sparse_categorical_accuracy: 0.7564
# Epoch 70/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9801 - val_loss: 1.1856 - val_sparse_categorical_accuracy: 0.7821
# Epoch 71/100
# 22/22 [==============================] - 8s 391ms/step - loss: 0.0574 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.6762 - val_sparse_categorical_accuracy: 0.7692
# Epoch 72/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9658 - val_loss: 1.2559 - val_sparse_categorical_accuracy: 0.7821
# Epoch 73/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0440 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.4698 - val_sparse_categorical_accuracy: 0.7692
# Epoch 74/100
# 22/22 [==============================] - 7s 325ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.7884 - val_sparse_categorical_accuracy: 0.8333
# Epoch 75/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9886 - val_loss: 1.7946 - val_sparse_categorical_accuracy: 0.7051
# Epoch 76/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0723 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.8604 - val_sparse_categorical_accuracy: 0.8077
# Epoch 77/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0568 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.7903 - val_sparse_categorical_accuracy: 0.8462
# Epoch 78/100
# 22/22 [==============================] - 7s 328ms/step - loss: 0.0603 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.9619 - val_sparse_categorical_accuracy: 0.8205
# Epoch 79/100
# 22/22 [==============================] - 8s 356ms/step - loss: 0.0366 - sparse_categorical_accuracy: 0.9858 - val_loss: 2.2258 - val_sparse_categorical_accuracy: 0.7179
# Epoch 80/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0606 - sparse_categorical_accuracy: 0.9729 - val_loss: 2.8308 - val_sparse_categorical_accuracy: 0.6795
# Epoch 81/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9815 - val_loss: 1.6691 - val_sparse_categorical_accuracy: 0.7436
# Epoch 82/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.9340 - val_sparse_categorical_accuracy: 0.8077
# Epoch 83/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0900 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.6002 - val_sparse_categorical_accuracy: 0.7564
# Epoch 84/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.7009 - val_sparse_categorical_accuracy: 0.8590
# Epoch 85/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0549 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.8309 - val_sparse_categorical_accuracy: 0.8333
# Epoch 86/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0769 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.7303 - val_sparse_categorical_accuracy: 0.8462
# Epoch 87/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9872 - val_loss: 2.1908 - val_sparse_categorical_accuracy: 0.6923
# Epoch 88/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0464 - sparse_categorical_accuracy: 0.9829 - val_loss: 1.1368 - val_sparse_categorical_accuracy: 0.8077
# Epoch 89/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0768 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.9699 - val_sparse_categorical_accuracy: 0.7949
# Epoch 90/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0560 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.9634 - val_sparse_categorical_accuracy: 0.7564
# Epoch 91/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9872 - val_loss: 1.0319 - val_sparse_categorical_accuracy: 0.7949
# Epoch 92/100
# 22/22 [==============================] - 7s 328ms/step - loss: 0.0663 - sparse_categorical_accuracy: 0.9772 - val_loss: 1.9011 - val_sparse_categorical_accuracy: 0.7179
# Epoch 93/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.5968 - val_sparse_categorical_accuracy: 0.7436
# Epoch 94/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9872 - val_loss: 1.6531 - val_sparse_categorical_accuracy: 0.7308
# Epoch 95/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0917 - sparse_categorical_accuracy: 0.9729 - val_loss: 1.2154 - val_sparse_categorical_accuracy: 0.7692
# Epoch 96/100
# 22/22 [==============================] - 7s 328ms/step - loss: 0.0762 - sparse_categorical_accuracy: 0.9772 - val_loss: 1.4617 - val_sparse_categorical_accuracy: 0.7692
# Epoch 97/100
# 22/22 [==============================] - 7s 327ms/step - loss: 0.0278 - sparse_categorical_accuracy: 0.9900 - val_loss: 2.2674 - val_sparse_categorical_accuracy: 0.6795
# Epoch 98/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9900 - val_loss: 1.6741 - val_sparse_categorical_accuracy: 0.7436
# Epoch 99/100
# 22/22 [==============================] - 7s 326ms/step - loss: 0.0434 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.8259 - val_sparse_categorical_accuracy: 0.8077
# Epoch 100/100
# 22/22 [==============================] - 8s 353ms/step - loss: 0.0607 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.1166 - val_sparse_categorical_accuracy: 0.7821

# %%
hist = history.history

plt.plot(hist['loss'], label=  'loss')
plt.plot(hist['val_loss'], label = 'val_loss')
plt.plot(hist['sparse_categorical_accuracy'], label='accuracy')
plt.plot(hist['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.legend()

# %%
# used to predict the model and visualize the orignal image with title of true and pred values
def predict_image(img_path, label):
    img1 = prepare_image(img_path) # preprocess the image
    res = incept_model.predict(np.expand_dims(img1, axis = 0)) # predict the image
    pred = classes[np.argmax(res)]

    # Visualize the image
    img = image.load_img(img_path)
    plt.imshow(np.array(img))
    plt.title(f'True: {label}\nPredicted: {pred}')

# %%
predict_image('/content/drive/MyDrive/breast ultra/benign/benign (100).png', 'benign')

# %%
predict_image('/content/drive/MyDrive/breast ultra/malignant/malignant (110).png', 'malignant')

# %%
predict_image('/content/drive/MyDrive/breast ultra/normal/normal (109).png', 'normal')
