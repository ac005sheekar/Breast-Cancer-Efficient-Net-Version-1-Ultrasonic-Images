# %%
###           Written and Executed By:            ####
###               Sheekar Banerjee                ####
###        Senior Software Engineer- AI & ML      ####

# Breast Cancer Detection
# Ultrasound Image
# Efficient-Net-B4 (EfficientNetB4)
# Accuracy 99.00 %

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, activations, optimizers, losses, metrics, initializers
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV3Small, MobileNet, InceptionV3
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input, decode_predictions
from tensorflow.keras.applications.densenet import preprocess_input, decode_predictions

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dir_path = '/content/drive/MyDrive/breast ultra'
IMAGE_SHAPE = (224, 224)

# %%
# create prepare_image method
# used to preprocess the image for efficientNet model
def prepare_image(file):
    img = image.load_img(file, target_size=IMAGE_SHAPE)
    img_array = image.img_to_array(img)
    return tf.keras.applications.efficientnet.preprocess_input (img_array)

# %%
directories = os.listdir(dir_path) # read the folders

files = [] # save all images for each folder
labels = [] # set for each image the name of it

# read files for each directory
for folder in directories:
    
    fileList = glob.glob(dir_path + '/'+ folder + '/*')
    labels.extend([folder for l in fileList])
    files.extend(fileList)
    
len(files), len(labels)
# Out:
# (1578, 1578)

# %%
# create two lists to hold only non-mask images and label for each one
selected_files = []
selected_labels = []

for file, label in zip(files, labels):
    if 'mask' not in file:
        selected_files.append(file)
        selected_labels.append(label)

    
len(selected_files), len(selected_labels)
# Out:
# (780, 780)

# %%
# the dictionary holds list of images and for each one has its target/label
images = {
    'image': [], 
    'target': []
}

print('Preparing the image...')

for i, (file, label) in enumerate(zip(selected_files, selected_labels)):
    images['image'].append(prepare_image(file))
    images['target'].append(label)

print('Finished.')
# Out:
# Preparing the image...
# Finished.

# %%
# convert lists to arrays 
images['image'] = np.array(images['image'])
images['target'] = np.array(images['target'])

# encode the target
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

images['target'] = le.fit_transform(images['target'])

classes = le.classes_ # get the classes for each target
print(f'the target classes are: {classes}')
# Out:
# the target classes are: ['benign' 'malignant' 'normal']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(images['image'], images['target'], test_size=.10)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((702, 224, 224, 3), (78, 224, 224, 3), (702,), (78,))

# %%
#Build Model

from keras.applications.efficientnet import EfficientNetB4

base_model = EfficientNetB4(
    include_top=False,
    weights='imagenet',
    input_shape=(*IMAGE_SHAPE, 3),
    classes=3)

# Freeze the base_model
base_model.trainable = False

# append my own layers on the top of the model for Transfer Learning
x = base_model.output

# 1st conv block
x = layers.Conv2D(256, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 2nd conv block
x = layers.Conv2D(128, 3, padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.GlobalAveragePooling2D(keepdims = True)(x)

# 1st FC layer
x = layers.Flatten()(x) 
x = layers.Dense(64)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# 2nd FC layer
x = layers.Dense(32, activation = 'relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(.2)(x)

x = layers.Dense(3, 'softmax')(x)

incept_model = keras.models.Model(inputs = base_model.input, outputs = x)

# compile the model
incept_model.compile(optimizer=optimizers.RMSprop(.001), loss = losses.sparse_categorical_crossentropy, metrics= [metrics.SparseCategoricalAccuracy()])

incept_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_5 (Rescaling)        (None, 224, 224, 3)  0           ['input_6[0][0]']
#
#  normalization_5 (Normalization  (None, 224, 224, 3)  7          ['rescaling_5[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['normalization_5[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 112, 112, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 112, 112, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 112, 112, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 112, 112, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 112, 112, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 112, 112, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 112, 112, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 112, 112, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 112, 112, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 112, 112, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 112, 112, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 112, 112, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 112, 112, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 112, 112, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 112, 112, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 113, 113, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 56, 56, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 56, 56, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 56, 56, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 56, 56, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 56, 56, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 56, 56, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 56, 56, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 56, 56, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 56, 56, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 56, 56, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 56, 56, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 56, 56, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 56, 56, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 56, 56, 192)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 192)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 56, 56, 32)   6144        ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 56, 56, 32)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 56, 56, 32)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 56, 56, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 59, 59, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 28, 28, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 28, 28, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 28, 28, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 28, 28, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 56)   10752       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 336)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 28, 28, 336)  8400       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 28, 28, 336)  1344       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 28, 28, 336)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 336)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 28, 28, 336)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 56)   18816       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 28, 28, 56)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 28, 28, 56)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 28, 28, 336)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 28, 28, 336)  8400       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 28, 28, 336)  1344       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 28, 28, 336)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 336)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 28, 28, 336)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 28, 28, 56)   18816       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 28, 28, 56)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 28, 28, 56)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 28, 28, 336)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 28, 28, 336)  8400       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 28, 28, 336)  1344       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 28, 28, 336)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 336)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 28, 28, 336)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 28, 28, 56)   18816       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 28, 28, 56)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 28, 28, 56)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 28, 28, 336)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 29, 29, 336)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 14, 14, 336)  3024       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 14, 14, 336)  1344       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 14, 14, 336)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 336)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 14, 14, 336)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 14, 14, 112)  37632       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 14, 14, 672)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 14, 14, 672)  6048       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 14, 14, 672)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 672)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 14, 14, 112)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 14, 14, 112)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 14, 14, 672)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 14, 14, 672)  6048       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 14, 14, 672)  0          ['block4c_bn[0][0]']
#  )
#
# ...
#  block6h_expand_bn (BatchNormal  (None, 7, 7, 1632)  6528        ['block6h_expand_conv[0][0]']
#  ization)
#
#  block6h_expand_activation (Act  (None, 7, 7, 1632)  0           ['block6h_expand_bn[0][0]']
#  ivation)
#
#  block6h_dwconv (DepthwiseConv2  (None, 7, 7, 1632)  40800       ['block6h_expand_activation[0][0]
#  D)                                                              ']
#
#  block6h_bn (BatchNormalization  (None, 7, 7, 1632)  6528        ['block6h_dwconv[0][0]']
#  )
#
#  block6h_activation (Activation  (None, 7, 7, 1632)  0           ['block6h_bn[0][0]']
#  )
#
#  block6h_se_squeeze (GlobalAver  (None, 1632)        0           ['block6h_activation[0][0]']
#  agePooling2D)
#
#  block6h_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6h_se_squeeze[0][0]']
#
#  block6h_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multiply)   (None, 7, 7, 1632)   0           ['block6h_activation[0][0]',
#                                                                   'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv2D)  (None, 7, 7, 272)    443904      ['block6h_se_excite[0][0]']
#
#  block6h_project_bn (BatchNorma  (None, 7, 7, 272)   1088        ['block6h_project_conv[0][0]']
#  lization)
#
#  block6h_drop (Dropout)         (None, 7, 7, 272)    0           ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)              (None, 7, 7, 272)    0           ['block6h_drop[0][0]',
#                                                                   'block6g_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 7, 7, 1632)   443904      ['block6h_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 7, 7, 1632)  6528        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 7, 7, 1632)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 7, 7, 1632)  14688       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 7, 7, 1632)  6528        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 7, 7, 1632)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1632)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 7, 7, 1632)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 7, 7, 448)    731136      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 7, 7, 448)   1792        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 7, 7, 2688)   1204224     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 7, 7, 2688)  10752       ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 7, 7, 2688)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 7, 7, 2688)  24192       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 7, 7, 2688)  10752       ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 7, 7, 2688)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2688)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2688)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 112)    301168      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2688)   303744      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 7, 7, 2688)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 7, 7, 448)    1204224     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 7, 7, 448)   1792        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 7, 7, 448)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 7, 7, 448)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 7, 7, 1792)   802816      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 1792)   7168        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 1792)   0           ['top_bn[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 256)    4129024     ['top_activation[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_20[0][0]']
#
#  global_average_pooling2d_10 (G  (None, 1, 1, 256)   0           ['activation_20[0][0]']
#  lobalAveragePooling2D)
#
#  conv2d_11 (Conv2D)             (None, 1, 1, 128)    295040      ['global_average_pooling2d_10[0][
#                                                                  0]']
#
#  batch_normalization_21 (BatchN  (None, 1, 1, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 1, 1, 128)    0           ['batch_normalization_21[0][0]']
#
#  global_average_pooling2d_11 (G  (None, 1, 1, 128)   0           ['activation_21[0][0]']
#  lobalAveragePooling2D)
#
#  flatten_5 (Flatten)            (None, 128)          0           ['global_average_pooling2d_11[0][
#                                                                  0]']
#
#  dense_15 (Dense)               (None, 64)           8256        ['flatten_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64)          256         ['dense_15[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 64)           0           ['batch_normalization_22[0][0]']
#
#  dense_16 (Dense)               (None, 32)           2080        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32)          128         ['dense_16[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32)           0           ['batch_normalization_23[0][0]']
#
#  dropout_5 (Dropout)            (None, 32)           0           ['activation_23[0][0]']
#
#  dense_17 (Dense)               (None, 3)            99          ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 22,110,242
# Trainable params: 4,435,459
# Non-trainable params: 17,674,783
# __________________________________________________________________________________________________

# %%
earlyStop = keras.callbacks.EarlyStopping(patience=60) 
best_model = keras.callbacks.ModelCheckpoint(filepath='breast_Neurals_sheekar.h5', save_best_only=True) 

with tf.device('/gpu:0'):
    history = incept_model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data=(x_test, y_test), callbacks=[earlyStop, best_model])
# Out:
# Epoch 1/100
# 22/22 [==============================] - 21s 369ms/step - loss: 0.9311 - sparse_categorical_accuracy: 0.5912 - val_loss: 0.8137 - val_sparse_categorical_accuracy: 0.6667
# Epoch 2/100
# 22/22 [==============================] - 5s 222ms/step - loss: 0.6457 - sparse_categorical_accuracy: 0.7564 - val_loss: 0.7575 - val_sparse_categorical_accuracy: 0.6923
# Epoch 3/100
# 22/22 [==============================] - 4s 180ms/step - loss: 0.5886 - sparse_categorical_accuracy: 0.7721 - val_loss: 0.7775 - val_sparse_categorical_accuracy: 0.7179
# Epoch 4/100
# 22/22 [==============================] - 5s 223ms/step - loss: 0.5267 - sparse_categorical_accuracy: 0.7963 - val_loss: 0.7386 - val_sparse_categorical_accuracy: 0.6667
# Epoch 5/100
# 22/22 [==============================] - 5s 224ms/step - loss: 0.4368 - sparse_categorical_accuracy: 0.8447 - val_loss: 0.6053 - val_sparse_categorical_accuracy: 0.7436
# Epoch 6/100
# 22/22 [==============================] - 5s 236ms/step - loss: 0.3571 - sparse_categorical_accuracy: 0.8590 - val_loss: 0.6029 - val_sparse_categorical_accuracy: 0.7436
# Epoch 7/100
# 22/22 [==============================] - 5s 224ms/step - loss: 0.3149 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.5980 - val_sparse_categorical_accuracy: 0.7436
# Epoch 8/100
# 22/22 [==============================] - 4s 182ms/step - loss: 0.3165 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.5986 - val_sparse_categorical_accuracy: 0.7564
# Epoch 9/100
# 22/22 [==============================] - 5s 225ms/step - loss: 0.2501 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.5490 - val_sparse_categorical_accuracy: 0.8077
# Epoch 10/100
# 22/22 [==============================] - 4s 184ms/step - loss: 0.2574 - sparse_categorical_accuracy: 0.9017 - val_loss: 0.6396 - val_sparse_categorical_accuracy: 0.7179
# Epoch 11/100
# 22/22 [==============================] - 4s 183ms/step - loss: 0.2011 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.6591 - val_sparse_categorical_accuracy: 0.7692
# Epoch 12/100
# 22/22 [==============================] - 4s 184ms/step - loss: 0.1930 - sparse_categorical_accuracy: 0.9373 - val_loss: 0.6065 - val_sparse_categorical_accuracy: 0.7692
# Epoch 13/100
# 22/22 [==============================] - 4s 196ms/step - loss: 0.2068 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.6832 - val_sparse_categorical_accuracy: 0.7949
# Epoch 14/100
# 22/22 [==============================] - 4s 185ms/step - loss: 0.1843 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.7117 - val_sparse_categorical_accuracy: 0.7949
# Epoch 15/100
# 22/22 [==============================] - 4s 185ms/step - loss: 0.1782 - sparse_categorical_accuracy: 0.9373 - val_loss: 0.8552 - val_sparse_categorical_accuracy: 0.7564
# Epoch 16/100
# 22/22 [==============================] - 4s 184ms/step - loss: 0.1666 - sparse_categorical_accuracy: 0.9444 - val_loss: 0.6142 - val_sparse_categorical_accuracy: 0.7692
# Epoch 17/100
# 22/22 [==============================] - 4s 185ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9658 - val_loss: 0.6047 - val_sparse_categorical_accuracy: 0.8205
# Epoch 18/100
# 22/22 [==============================] - 4s 197ms/step - loss: 0.1610 - sparse_categorical_accuracy: 0.9430 - val_loss: 0.6644 - val_sparse_categorical_accuracy: 0.7564
# Epoch 19/100
# 22/22 [==============================] - 4s 186ms/step - loss: 0.1647 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.8126 - val_sparse_categorical_accuracy: 0.7949
# Epoch 20/100
# 22/22 [==============================] - 4s 197ms/step - loss: 0.1016 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.7242 - val_sparse_categorical_accuracy: 0.8077
# Epoch 21/100
# 22/22 [==============================] - 5s 229ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9402 - val_loss: 0.4900 - val_sparse_categorical_accuracy: 0.8205
# Epoch 22/100
# 22/22 [==============================] - 4s 198ms/step - loss: 0.1029 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.6003 - val_sparse_categorical_accuracy: 0.8462
# Epoch 23/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.1177 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.5482 - val_sparse_categorical_accuracy: 0.8205
# Epoch 24/100
# 22/22 [==============================] - 5s 231ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9487 - val_loss: 0.3986 - val_sparse_categorical_accuracy: 0.8718
# Epoch 25/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9786 - val_loss: 0.9332 - val_sparse_categorical_accuracy: 0.7692
# Epoch 26/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.1312 - sparse_categorical_accuracy: 0.9587 - val_loss: 0.7249 - val_sparse_categorical_accuracy: 0.8333
# Epoch 27/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.4376 - val_sparse_categorical_accuracy: 0.8462
# Epoch 28/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0961 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.7384 - val_sparse_categorical_accuracy: 0.8205
# Epoch 29/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.1078 - sparse_categorical_accuracy: 0.9587 - val_loss: 0.9171 - val_sparse_categorical_accuracy: 0.8205
# Epoch 30/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0864 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.4184 - val_sparse_categorical_accuracy: 0.7692
# Epoch 31/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0943 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.1589 - val_sparse_categorical_accuracy: 0.7564
# Epoch 32/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.7308 - val_sparse_categorical_accuracy: 0.8205
# Epoch 33/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0849 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.8904 - val_sparse_categorical_accuracy: 0.7821
# Epoch 34/100
# 22/22 [==============================] - 4s 191ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.9005 - val_sparse_categorical_accuracy: 0.8077
# Epoch 35/100
# 22/22 [==============================] - 4s 190ms/step - loss: 0.0787 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.5202 - val_sparse_categorical_accuracy: 0.8205
# Epoch 36/100
# 22/22 [==============================] - 4s 199ms/step - loss: 0.0830 - sparse_categorical_accuracy: 0.9744 - val_loss: 0.7523 - val_sparse_categorical_accuracy: 0.7949
# Epoch 37/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.5490 - val_sparse_categorical_accuracy: 0.8462
# Epoch 38/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9786 - val_loss: 0.8108 - val_sparse_categorical_accuracy: 0.8333
# Epoch 39/100
# 22/22 [==============================] - 4s 198ms/step - loss: 0.0724 - sparse_categorical_accuracy: 0.9687 - val_loss: 1.3051 - val_sparse_categorical_accuracy: 0.7564
# Epoch 40/100
# 22/22 [==============================] - 4s 197ms/step - loss: 0.0840 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.1502 - val_sparse_categorical_accuracy: 0.7564
# Epoch 41/100
# 22/22 [==============================] - 4s 198ms/step - loss: 0.0770 - sparse_categorical_accuracy: 0.9687 - val_loss: 0.6376 - val_sparse_categorical_accuracy: 0.7949
# Epoch 42/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0664 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.0099 - val_sparse_categorical_accuracy: 0.8205
# Epoch 43/100
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.9849 - val_sparse_categorical_accuracy: 0.7821
# Epoch 44/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0561 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.8910 - val_sparse_categorical_accuracy: 0.8590
# Epoch 45/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0746 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.7136 - val_sparse_categorical_accuracy: 0.8333
# Epoch 46/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.8189 - val_sparse_categorical_accuracy: 0.8590
# Epoch 47/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0605 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.6387 - val_sparse_categorical_accuracy: 0.7692
# Epoch 48/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.1057 - sparse_categorical_accuracy: 0.9672 - val_loss: 1.1348 - val_sparse_categorical_accuracy: 0.8077
# Epoch 49/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.0113 - val_sparse_categorical_accuracy: 0.8333
# Epoch 50/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.7140 - val_sparse_categorical_accuracy: 0.8205
# Epoch 51/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0493 - sparse_categorical_accuracy: 0.9772 - val_loss: 0.8590 - val_sparse_categorical_accuracy: 0.8333
# Epoch 52/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0668 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.8740 - val_sparse_categorical_accuracy: 0.8333
# Epoch 53/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.9088 - val_sparse_categorical_accuracy: 0.8462
# Epoch 54/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0549 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.0965 - val_sparse_categorical_accuracy: 0.7949
# Epoch 55/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0553 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.7019 - val_sparse_categorical_accuracy: 0.8462
# Epoch 56/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0537 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.1680 - val_sparse_categorical_accuracy: 0.7821
# Epoch 57/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.0966 - val_sparse_categorical_accuracy: 0.8205
# Epoch 58/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9801 - val_loss: 1.0596 - val_sparse_categorical_accuracy: 0.8077
# Epoch 59/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0494 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.5983 - val_sparse_categorical_accuracy: 0.7949
# Epoch 60/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9744 - val_loss: 1.4314 - val_sparse_categorical_accuracy: 0.7821
# Epoch 61/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0592 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.9461 - val_sparse_categorical_accuracy: 0.8205
# Epoch 62/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.0672 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.0287 - val_sparse_categorical_accuracy: 0.7949
# Epoch 63/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9829 - val_loss: 1.3641 - val_sparse_categorical_accuracy: 0.7949
# Epoch 64/100
# 22/22 [==============================] - 4s 199ms/step - loss: 0.0626 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.8879 - val_sparse_categorical_accuracy: 0.8462
# Epoch 65/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0604 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.9329 - val_sparse_categorical_accuracy: 0.8462
# Epoch 66/100
# 22/22 [==============================] - 4s 199ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.9716 - val_sparse_categorical_accuracy: 0.8333
# Epoch 67/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0355 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.3384 - val_sparse_categorical_accuracy: 0.7949
# Epoch 68/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0494 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.0626 - val_sparse_categorical_accuracy: 0.7949
# Epoch 69/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0754 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.9366 - val_sparse_categorical_accuracy: 0.8205
# Epoch 70/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0624 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.0856 - val_sparse_categorical_accuracy: 0.8205
# Epoch 71/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.9560 - val_sparse_categorical_accuracy: 0.8205
# Epoch 72/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.1003 - sparse_categorical_accuracy: 0.9687 - val_loss: 1.3800 - val_sparse_categorical_accuracy: 0.8333
# Epoch 73/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0321 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.3197 - val_sparse_categorical_accuracy: 0.7821
# Epoch 74/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9829 - val_loss: 1.1843 - val_sparse_categorical_accuracy: 0.8333
# Epoch 75/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0585 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.9449 - val_sparse_categorical_accuracy: 0.8333
# Epoch 76/100
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.8418 - val_sparse_categorical_accuracy: 0.8333
# Epoch 77/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9915 - val_loss: 1.1159 - val_sparse_categorical_accuracy: 0.8205
# Epoch 78/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.0692 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.4724 - val_sparse_categorical_accuracy: 0.8205
# Epoch 79/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9915 - val_loss: 1.3052 - val_sparse_categorical_accuracy: 0.8077
# Epoch 80/100
# 22/22 [==============================] - 4s 188ms/step - loss: 0.0632 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.3455 - val_sparse_categorical_accuracy: 0.7949
# Epoch 81/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.0596 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.1376 - val_sparse_categorical_accuracy: 0.8205
# Epoch 82/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.0638 - val_sparse_categorical_accuracy: 0.8205
# Epoch 83/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.0524 - sparse_categorical_accuracy: 0.9772 - val_loss: 1.0864 - val_sparse_categorical_accuracy: 0.8590
# Epoch 84/100
# 22/22 [==============================] - 4s 189ms/step - loss: 0.0275 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.9281 - val_sparse_categorical_accuracy: 0.7949

# %%
hist = history.history

plt.plot(hist['loss'], label=  'loss')
plt.plot(hist['val_loss'], label = 'val_loss')
plt.plot(hist['sparse_categorical_accuracy'], label='accuracy')
plt.plot(hist['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.legend()

# %%
# used to predict the model and visualize the orignal image with title of true and pred values
def predict_image(img_path, label):
    img1 = prepare_image(img_path) # preprocess the image
    res = incept_model.predict(np.expand_dims(img1, axis = 0)) # predict the image
    pred = classes[np.argmax(res)]

    # Visualize the image
    img = image.load_img(img_path)
    plt.imshow(np.array(img))
    plt.title(f'True: {label}\nPredicted: {pred}')

# %%
predict_image('/content/drive/MyDrive/breast ultra/benign/benign (100).png', 'benign')
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd453ba0e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predict_image('/content/drive/MyDrive/breast ultra/malignant/malignant (110).png', 'malignant')

# %%
predict_image('/content/drive/MyDrive/breast ultra/normal/normal (109).png', 'normal')
